# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                               source  \
# 0               {'id': 'reuters', 'name': 'Reuters'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2  {'id': 'business-insider', 'name': 'Business I...
# 3                {'id': None, 'name': 'VentureBeat'}
# 4                {'id': None, 'name': 'VentureBeat'}
#
#                                               author  \
# 0                                                NaN
# 1                insider@insider.com (Yanet Borrego)
# 2                       amok@insider.com (Aaron Mok)
# 3                                     Dean Takahashi
# 4  Michael Biltz, Accenture Labs, Marc Carrel-Bil...
#
#                                                title  \
# 0  IBM reports highest annual revenue growth in a...
# 1  I was a career coach on the side for years bef...
# 2  How people are making money on Canva and turni...
# 3  Consumer and business interest in the metavers...
# 4  Plan now for the internetâ€™s transformation b...
#
#                                          description  \
# 0  IBM Corp <a href="https://www.reuters.com/comp...
# 1  Yanet Borrego spent nine years as an engineer ...
# 2  Workers are leaving their full-time jobs to st...
# 3  Consumers and businesses are getting more inte...
# 4  How Web3 and the metaverse will transform the ...
#
#                                                  url  \
# 0  https://www.reuters.com/technology/ibm-reports...
# 1  https://www.businessinsider.com/quit-6-figure-...
# 2  https://www.businessinsider.com/workers-leavin...
# 3  https://venturebeat.com/games/consumer-and-bus...
# 4  https://venturebeat.com/virtual/plan-now-for-t...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.reuters.com/resizer/FjOhONjPelMPMz...  2023-01-25T21:12:00Z
# 1  https://i.insider.com/63c98aeceee94d001a78fbc5...  2023-01-23T18:55:16Z
# 2  https://i.insider.com/63612637ade71a00193dc7db...  2023-01-28T14:08:25Z
# 3  https://venturebeat.com/wp-content/uploads/202...  2023-01-04T13:00:00Z
# 4  https://venturebeat.com/wp-content/uploads/202...  2023-01-29T16:20:00Z
#
#                                              content
# 0  Jan 25 (Reuters) - IBM Corp (IBM.N) on Wednesd...
# 1  I spent seven years at ExxonMobil and two year...
# 2  After a tech startup fired 31-year-old Shruti ...
# 3  Connect with gaming and metaverse leaders onli...
# 4  Check out all the on-demand sessions from the ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def fine_grained_sentimental_analysis(content):   
    tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
    model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")   
    tokens = tokenizer.encode(content, return_tensors='pt', truncation=True, padding=True)
    result = model(tokens)
    result.logits
    sentiment_score = int(torch.argmax(result.logits))+1
    return sentiment_score

# %%
import spacy

# load english language model and create nlp object from it
nlp = spacy.load("en_core_web_sm") 


#use this utility function to get the preprocessed text data
def preprocess(text):
    # remove stop words and lemmatize the text
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
    
    return " ".join(filtered_tokens)

# %%
df['preprocessed_title'] = df['title'].apply(preprocess)

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                               source  \
# 0               {'id': 'reuters', 'name': 'Reuters'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2  {'id': 'business-insider', 'name': 'Business I...
# 3                {'id': None, 'name': 'VentureBeat'}
# 4                {'id': None, 'name': 'VentureBeat'}
#
#                                               author  \
# 0                                                NaN
# 1                insider@insider.com (Yanet Borrego)
# 2                       amok@insider.com (Aaron Mok)
# 3                                     Dean Takahashi
# 4  Michael Biltz, Accenture Labs, Marc Carrel-Bil...
#
#                                                title  \
# 0  IBM reports highest annual revenue growth in a...
# 1  I was a career coach on the side for years bef...
# 2  How people are making money on Canva and turni...
# 3  Consumer and business interest in the metavers...
# 4  Plan now for the internetâ€™s transformation b...
#
#                                          description  \
# 0  IBM Corp <a href="https://www.reuters.com/comp...
# 1  Yanet Borrego spent nine years as an engineer ...
# 2  Workers are leaving their full-time jobs to st...
# 3  Consumers and businesses are getting more inte...
# 4  How Web3 and the metaverse will transform the ...
#
#                                                  url  \
# 0  https://www.reuters.com/technology/ibm-reports...
# 1  https://www.businessinsider.com/quit-6-figure-...
# 2  https://www.businessinsider.com/workers-leavin...
# 3  https://venturebeat.com/games/consumer-and-bus...
# 4  https://venturebeat.com/virtual/plan-now-for-t...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.reuters.com/resizer/FjOhONjPelMPMz...  2023-01-25T21:12:00Z
# 1  https://i.insider.com/63c98aeceee94d001a78fbc5...  2023-01-23T18:55:16Z
# 2  https://i.insider.com/63612637ade71a00193dc7db...  2023-01-28T14:08:25Z
# 3  https://venturebeat.com/wp-content/uploads/202...  2023-01-04T13:00:00Z
# 4  https://venturebeat.com/wp-content/uploads/202...  2023-01-29T16:20:00Z
#
#                                              content  \
# 0  Jan 25 (Reuters) - IBM Corp (IBM.N) on Wednesd...
# 1  I spent seven years at ExxonMobil and two year...
# 2  After a tech startup fired 31-year-old Shruti ...
# 3  Connect with gaming and metaverse leaders onli...
# 4  Check out all the on-demand sessions from the ...
#
#                                   preprocessed_title
# 0  IBM report high annual revenue growth decade r...
# 1  career coach year quit 6 figure consulting job...
# 2  people make money Canva turn graphic design hu...
# 3  consumer business interest metaverse grow | ac...
# 4  plan internetâ€ ™ s transformation metaverse Web3

# %%
df['score'] = df['preprocessed_title'].apply(fine_grained_sentimental_analysis)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
# 5             5           5
# 6             6           6
# 7             7           7
# 8             8           8
# 9             9           9
#
#                                               source  \
# 0               {'id': 'reuters', 'name': 'Reuters'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2  {'id': 'business-insider', 'name': 'Business I...
# 3                {'id': None, 'name': 'VentureBeat'}
# 4                {'id': None, 'name': 'VentureBeat'}
# 5     {'id': 'the-next-web', 'name': 'The Next Web'}
# 6                {'id': None, 'name': 'MarketWatch'}
# 7            {'id': None, 'name': 'Theregister.com'}
# 8                   {'id': None, 'name': 'Techdirt'}
# 9                {'id': None, 'name': 'Motley Fool'}
#
#                                               author  \
# 0                                                NaN
# 1                insider@insider.com (Yanet Borrego)
# 2                       amok@insider.com (Aaron Mok)
# 3                                     Dean Takahashi
# 4  Michael Biltz, Accenture Labs, Marc Carrel-Bil...
# 5                                    Thomas Macaulay
# 6                                    Jeremy C. Owens
# 7                                        Paul Kunert
# 8                                        Tim Cushing
# 9              newsfeedback@fool.com (Jeremy Bowman)
#
#                                                title  \
# 0  IBM reports highest annual revenue growth in a...
# 1  I was a career coach on the side for years bef...
# 2  How people are making money on Canva and turni...
# 3  Consumer and business interest in the metavers...
# 4  Plan now for the internetâ€™s transformation b...
# 5  EU tech policy predictions: What to expect in ...
# 6  : Tesla is not alone: 18 (and a half) other bi...
# 7  Corporations start testing Windows 11 in bigge...
# 8  Government Continues To Rely On Private Contra...
# 9  Tired of Volatility? Consider These 2 Tech Stocks
#
#                                          description  \
# 0  IBM Corp <a href="https://www.reuters.com/comp...
# 1  Yanet Borrego spent nine years as an engineer ...
# 2  Workers are leaving their full-time jobs to st...
# 3  Consumers and businesses are getting more inte...
# 4  How Web3 and the metaverse will transform the ...
# 5  The European Union has an unusual IT strategy....
# 6  Meta Platforms and PayPal are also among S&P 1...
# 7  Accensure and L'Oreal among biz users, yet gen...
# 8  Thereâ€™s only so much domestic surveillance t...
# 9  Not every tech stock is struggling with macro ...
#
#                                                  url  \
# 0  https://www.reuters.com/technology/ibm-reports...
# 1  https://www.businessinsider.com/quit-6-figure-...
# 2  https://www.businessinsider.com/workers-leavin...
# 3  https://venturebeat.com/games/consumer-and-bus...
# 4  https://venturebeat.com/virtual/plan-now-for-t...
# 5  https://thenextweb.com/news/eu-tech-policy-pre...
# 6  https://www.marketwatch.com/story/tesla-is-not...
# 7  https://www.theregister.com/2023/01/05/corpora...
# 8  https://www.techdirt.com/2023/01/05/government...
# 9  https://www.fool.com/investing/2023/01/20/tire...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.reuters.com/resizer/FjOhONjPelMPMz...  2023-01-25T21:12:00Z
# 1  https://i.insider.com/63c98aeceee94d001a78fbc5...  2023-01-23T18:55:16Z
# 2  https://i.insider.com/63612637ade71a00193dc7db...  2023-01-28T14:08:25Z
# 3  https://venturebeat.com/wp-content/uploads/202...  2023-01-04T13:00:00Z
# 4  https://venturebeat.com/wp-content/uploads/202...  2023-01-29T16:20:00Z
# 5  https://img-cdn.tnwcdn.com/image/tnw?filter_la...  2022-12-31T10:00:34Z
# 6           https://images.mktw.net/im-587536/social  2022-12-30T00:59:00Z
# 7     https://regmedia.co.uk/2021/07/21/chen_new.jpg  2023-01-05T14:00:15Z
# 8  https://www.techdirt.com/wp-content/themes/tec...  2023-01-05T17:18:58Z
# 9  https://g.foolcdn.com/editorial/images/717114/...  2023-01-20T21:00:00Z
#
#                                              content  \
# 0  Jan 25 (Reuters) - IBM Corp (IBM.N) on Wednesd...
# 1  I spent seven years at ExxonMobil and two year...
# 2  After a tech startup fired 31-year-old Shruti ...
# 3  Connect with gaming and metaverse leaders onli...
# 4  Check out all the on-demand sessions from the ...
# 5  The European Union has an unusual IT strategy....
# 6  In the worst year for stocks since the Great R...
# 7  Large corporations are starting to run Windows...
# 8  from the ongoing-inconvenience-of-guaranteed-r...
# 9  Last year was a wake-up call for tech investor...
#
#                                   preprocessed_title  score
# 0  IBM report high annual revenue growth decade r...      5
# 1  career coach year quit 6 figure consulting job...      5
# 2  people make money Canva turn graphic design hu...      5
# 3  consumer business interest metaverse grow | ac...      5
# 4  plan internetâ€ ™ s transformation metaverse Web3      4
# 5              EU tech policy prediction expect 2023      3
# 6       Tesla 18 half big stock head bad year record      1
# 7  corporation start test Windows 11 big number g...      1
# 8  government continue rely private contractor By...      1
# 9             tired volatility consider 2 tech stock      1

# %%
df['score'].value_counts()
# Out:
# 5    66
# 1    15
# 4     9
# 3     8
# 2     1
# Name: score, dtype: int64

# %%
df['sentiment'] = df['score'].map({
    5: "Very Positive",
    4: "Positive",
    3: "Neutral",
    2: "Negative",
    1: "Very Negative"
})

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                               source  \
# 0               {'id': 'reuters', 'name': 'Reuters'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2  {'id': 'business-insider', 'name': 'Business I...
# 3                {'id': None, 'name': 'VentureBeat'}
# 4                {'id': None, 'name': 'VentureBeat'}
#
#                                               author  \
# 0                                                NaN
# 1                insider@insider.com (Yanet Borrego)
# 2                       amok@insider.com (Aaron Mok)
# 3                                     Dean Takahashi
# 4  Michael Biltz, Accenture Labs, Marc Carrel-Bil...
#
#                                                title  \
# 0  IBM reports highest annual revenue growth in a...
# 1  I was a career coach on the side for years bef...
# 2  How people are making money on Canva and turni...
# 3  Consumer and business interest in the metavers...
# 4  Plan now for the internetâ€™s transformation b...
#
#                                          description  \
# 0  IBM Corp <a href="https://www.reuters.com/comp...
# 1  Yanet Borrego spent nine years as an engineer ...
# 2  Workers are leaving their full-time jobs to st...
# 3  Consumers and businesses are getting more inte...
# 4  How Web3 and the metaverse will transform the ...
#
#                                                  url  \
# 0  https://www.reuters.com/technology/ibm-reports...
# 1  https://www.businessinsider.com/quit-6-figure-...
# 2  https://www.businessinsider.com/workers-leavin...
# 3  https://venturebeat.com/games/consumer-and-bus...
# 4  https://venturebeat.com/virtual/plan-now-for-t...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.reuters.com/resizer/FjOhONjPelMPMz...  2023-01-25T21:12:00Z
# 1  https://i.insider.com/63c98aeceee94d001a78fbc5...  2023-01-23T18:55:16Z
# 2  https://i.insider.com/63612637ade71a00193dc7db...  2023-01-28T14:08:25Z
# 3  https://venturebeat.com/wp-content/uploads/202...  2023-01-04T13:00:00Z
# 4  https://venturebeat.com/wp-content/uploads/202...  2023-01-29T16:20:00Z
#
#                                              content  \
# 0  Jan 25 (Reuters) - IBM Corp (IBM.N) on Wednesd...
# 1  I spent seven years at ExxonMobil and two year...
# 2  After a tech startup fired 31-year-old Shruti ...
# 3  Connect with gaming and metaverse leaders onli...
# 4  Check out all the on-demand sessions from the ...
#
#                                   preprocessed_title  score      sentiment
# 0  IBM report high annual revenue growth decade r...      5  Very Positive
# 1  career coach year quit 6 figure consulting job...      5  Very Positive
# 2  people make money Canva turn graphic design hu...      5  Very Positive
# 3  consumer business interest metaverse grow | ac...      5  Very Positive
# 4  plan internetâ€ ™ s transformation metaverse Web3      4       Positive

# %%
df.to_csv('file.csv')
